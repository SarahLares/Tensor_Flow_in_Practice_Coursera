# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahLares/Tensor_Flow_in_Practice_Coursera/blob/master/Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):
    xs = np.array([0, 1, 2, 3, 4, 5, 6], dtype=float)
    ys = np.array([0.5, 1.0, 1.5, 2.0,2.5, 3.0, 3.5], dtype=float)
    model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])
    model.compile(optimizer='sgd', loss = 'mean_squared_error')
    model.fit(xs, ys, epochs = 1200)
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/1200
# 7/7 [==============================] - 0s 52ms/sample - loss: 0.1480
# Epoch 2/1200
# 7/7 [==============================] - 0s 211us/sample - loss: 0.1158
# Epoch 3/1200
# 7/7 [==============================] - 0s 206us/sample - loss: 0.0984
# Epoch 4/1200
# 7/7 [==============================] - 0s 172us/sample - loss: 0.0888
# Epoch 5/1200
# 7/7 [==============================] - 0s 200us/sample - loss: 0.0833
# Epoch 6/1200
# 7/7 [==============================] - 0s 181us/sample - loss: 0.0800
# Epoch 7/1200
# 7/7 [==============================] - 0s 12ms/sample - loss: 0.0779
# Epoch 8/1200
# 7/7 [==============================] - 0s 217us/sample - loss: 0.0763
# Epoch 9/1200
# 7/7 [==============================] - 0s 228us/sample - loss: 0.0751
# Epoch 10/1200
# 7/7 [==============================] - 0s 208us/sample - loss: 0.0740
# Epoch 11/1200
# 7/7 [==============================] - 0s 183us/sample - loss: 0.0731
# Epoch 12/1200
# ...

# %%
# Now click the 'Submit Assignment' button above.
# Once that is complete, please run the following two cells to save your work and close the notebook

# %%
# %%javascript
# <!-- Save the notebook -->
# IPython.notebook.save_checkpoint();

# %%
# %%javascript
# IPython.notebook.session.delete();
# window.onbeforeunload = null
# setTimeout(function() { window.close(); }, 1000);
